# %%
import pandas as pd

# %%
df = pd.read_excel('C:\\Users\\BIT\\Downloads\\Complain.xlsx')

# %%
df['Domain'].unique()
# Out:
# array(['Transaction Fail', 'Netbanking', 'Mortgage', 'Loan', 'Debit Card',
#        'Customer Service', 'Credit card', 'ATM', 'Interest Rate', 'Stock',
#        'Salary', 'Transaction Failure', 'Tax', 'Credit Card',
#        'Financial Apps', 'Consumer transaction complaints', 'Transaction',
#        'Retail Banking', 'Crypto', 'Refund', 'Retail banking', 'Economy',
#        'Debit card', 'Stocks and investment', 'Financial Policies'],
#       dtype=object)

# %%
df
# Out:
#                   Domain                                 Complaint/ Opinion  \
# 0       Transaction Fail  Can someone tell me if transaction fail betwee...
# 1       Transaction Fail  @LICIndiaForever @Paytmcare @Paytm As part of ...
# 2       Transaction Fail  @ICICIBank_Care This is something very serious...
# 3       Transaction Fail  @RBI @ICICIBank_Care @ICICIBank @CRED_support ...
# 4       Transaction Fail  Fraud transaction through CRED for SBI C-Card ...
# ...                  ...                                                ...
# 6275  Financial Policies  If your implication is that policies to reduce...
# 6276  Financial Policies  Banks being put on notice regarding climate ch...
# 6277  Financial Policies  How Will the Stock Market Do in 2022? Expect a...
# 6278  Financial Policies  Goodbye, punch bowl. We’re going to miss you. ...
# 6279  Financial Policies  What are the company’s policies and processes ...
#
# ...
